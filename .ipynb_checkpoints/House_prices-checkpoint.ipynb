# %%
# !ls

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# from google.colab import files
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import xgboost
import catboost
import seaborn

from sklearn import linear_model, preprocessing, model_selection

# %%
def rmse_cv(model, X, y):
    rmse= np.sqrt(-model_selection.cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv = 5))
    return(round(rmse.mean(), 5))

# %%
data_train = pd.read_csv('train.csv')
data_train = data_train.drop(data_train[(data_train['GrLivArea']>4000) & (data_train['SalePrice']<300000)].index)

data_test = pd.read_csv('test.csv')

# %%
display(data_train.head(5))
print('shape:', data_train.shape)
print()
data_train.info()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]
# shape: (1458, 81)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1458 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1458 non-null int64
# MSSubClass       1458 non-null int64
# MSZoning         1458 non-null object
# LotFrontage      1199 non-null float64
# LotArea          1458 non-null int64
# Street           1458 non-null object
# Alley            91 non-null object
# LotShape         1458 non-null object
# LandContour      1458 non-null object
# Utilities        1458 non-null object
# LotConfig        1458 non-null object
# LandSlope        1458 non-null object
# Neighborhood     1458 non-null object
# Condition1       1458 non-null object
# Condition2       1458 non-null object
# BldgType         1458 non-null object
# HouseStyle       1458 non-null object
# OverallQual      1458 non-null int64
# OverallCond      1458 non-null int64
# YearBuilt        1458 non-null int64
# YearRemodAdd     1458 non-null int64
# RoofStyle        1458 non-null object
# RoofMatl         1458 non-null object
# Exterior1st      1458 non-null object
# Exterior2nd      1458 non-null object
# MasVnrType       1450 non-null object
# MasVnrArea       1450 non-null float64
# ExterQual        1458 non-null object
# ExterCond        1458 non-null object
# Foundation       1458 non-null object
# BsmtQual         1421 non-null object
# BsmtCond         1421 non-null object
# BsmtExposure     1420 non-null object
# BsmtFinType1     1421 non-null object
# BsmtFinSF1       1458 non-null int64
# BsmtFinType2     1420 non-null object
# BsmtFinSF2       1458 non-null int64
# BsmtUnfSF        1458 non-null int64
# TotalBsmtSF      1458 non-null int64
# Heating          1458 non-null object
# HeatingQC        1458 non-null object
# CentralAir       1458 non-null object
# Electrical       1457 non-null object
# 1stFlrSF         1458 non-null int64
# 2ndFlrSF         1458 non-null int64
# LowQualFinSF     1458 non-null int64
# GrLivArea        1458 non-null int64
# BsmtFullBath     1458 non-null int64
# BsmtHalfBath     1458 non-null int64
# FullBath         1458 non-null int64
# HalfBath         1458 non-null int64
# BedroomAbvGr     1458 non-null int64
# KitchenAbvGr     1458 non-null int64
# KitchenQual      1458 non-null object
# TotRmsAbvGrd     1458 non-null int64
# Functional       1458 non-null object
# Fireplaces       1458 non-null int64
# FireplaceQu      768 non-null object
# GarageType       1377 non-null object
# GarageYrBlt      1377 non-null float64
# GarageFinish     1377 non-null object
# GarageCars       1458 non-null int64
# GarageArea       1458 non-null int64
# GarageQual       1377 non-null object
# GarageCond       1377 non-null object
# PavedDrive       1458 non-null object
# WoodDeckSF       1458 non-null int64
# OpenPorchSF      1458 non-null int64
# EnclosedPorch    1458 non-null int64
# 3SsnPorch        1458 non-null int64
# ScreenPorch      1458 non-null int64
# PoolArea         1458 non-null int64
# PoolQC           6 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1458 non-null int64
# MoSold           1458 non-null int64
# YrSold           1458 non-null int64
# SaleType         1458 non-null object
# SaleCondition    1458 non-null object
# SalePrice        1458 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 934.0+ KB

# %%
for index, i in enumerate(np.sum(data_train.isnull())):
    if i != 0:
        print(np.sum(data_train.isnull()).index[index], i)
# Out:
# LotFrontage 259
# Alley 1367
# MasVnrType 8
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1452
# Fence 1177
# MiscFeature 1404

# %%
plt.figure(figsize=(20,20))
seaborn.heatmap(data_train.corr(), cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10})
plt.show()

# %%
df_train_test = pd.concat((data_train.loc[:,'MSSubClass':'SaleCondition'],
                      data_test.loc[:,'MSSubClass':'SaleCondition']))

# %%
df_train_test['TotalSF'] = df_train_test['TotalBsmtSF'] + df_train_test['1stFlrSF'] + df_train_test['2ndFlrSF']

#price per feet engineering:
#cost of 1 square feet of living area per house by Neighborhood groups
#Its a kind of mean encoding (or likehood encoding)
data_train['DolPerFeetLiv'] = data_train['SalePrice']/data_train['GrLivArea']
data = pd.concat([data_train['Neighborhood'], data_train['DolPerFeetLiv']], axis=1)
cost_per_district = data.groupby('Neighborhood')['DolPerFeetLiv'].mean()
df_train_test['DolPerFeetNeigLiv'] = df_train_test['Neighborhood'].apply(lambda x: cost_per_district[x])

#cost of 1 square feet of lot area per house by Neighborhood groups
data_train['DolPerFeetLot'] = data_train['SalePrice']/data_train['LotArea']
data = pd.concat([data_train['Neighborhood'], data_train['DolPerFeetLot']], axis=1)
cost_per_district = data.groupby('Neighborhood')['DolPerFeetLot'].mean()
df_train_test['DolPerFeetNeigLot'] = df_train_test['Neighborhood'].apply(lambda x: cost_per_district[x])

# %%
df_train_test.shape
# Out:
# (2917, 82)

# %%
def clear_data(df):
    # Источник - https://www.kaggle.com/juliencs/a-study-on-regression-applied-to-the-ames-dataset  

    # Заполняем отсутсвующие значения
    # Alley : data description says NA means "no alley access"
    df["Alley"] = df["Alley"].fillna("None")
    # BedroomAbvGr : NA most likely means 0
    df.loc[:, "BedroomAbvGr"] = df.loc[:, "BedroomAbvGr"].fillna(0)
    # BsmtQual etc : data description says NA for basement features is "no basement"
    df.loc[:, "BsmtQual"] = df.loc[:, "BsmtQual"].fillna("No")
    df.loc[:, "BsmtCond"] = df.loc[:, "BsmtCond"].fillna("No")
    df.loc[:, "BsmtExposure"] = df.loc[:, "BsmtExposure"].fillna("No")
    df.loc[:, "BsmtFinType1"] = df.loc[:, "BsmtFinType1"].fillna("No")
    df.loc[:, "BsmtFinType2"] = df.loc[:, "BsmtFinType2"].fillna("No")
    df.loc[:, "BsmtFullBath"] = df.loc[:, "BsmtFullBath"].fillna(0)
    df.loc[:, "BsmtHalfBath"] = df.loc[:, "BsmtHalfBath"].fillna(0)
    df.loc[:, "BsmtUnfSF"] = df.loc[:, "BsmtUnfSF"].fillna(0)
    # CentralAir : NA most likely means No
    df.loc[:, "CentralAir"] = df.loc[:, "CentralAir"].fillna("N")
    # Condition : NA most likely means Normal
    df.loc[:, "Condition1"] = df.loc[:, "Condition1"].fillna("Norm")
    df.loc[:, "Condition2"] = df.loc[:, "Condition2"].fillna("Norm")
    # EnclosedPorch : NA most likely means no enclosed porch
    df.loc[:, "EnclosedPorch"] = df.loc[:, "EnclosedPorch"].fillna(0)
    # External stuff : NA most likely means average
    df.loc[:, "ExterCond"] = df.loc[:, "ExterCond"].fillna("TA")
    df.loc[:, "ExterQual"] = df.loc[:, "ExterQual"].fillna("TA")
    # Fence : data description says NA means "no fence"
    df.loc[:, "Fence"] = df.loc[:, "Fence"].fillna("No")
    # FireplaceQu : data description says NA means "no fireplace"
    df.loc[:, "FireplaceQu"] = df.loc[:, "FireplaceQu"].fillna("No")
    df.loc[:, "Fireplaces"] = df.loc[:, "Fireplaces"].fillna(0)
    # Functional : data description says NA means typical
    df.loc[:, "Functional"] = df.loc[:, "Functional"].fillna("Typ")
    # GarageType etc : data description says NA for garage features is "no garage"
    df.loc[:, "GarageType"] = df.loc[:, "GarageType"].fillna("No")
    df.loc[:, "GarageFinish"] = df.loc[:, "GarageFinish"].fillna("No")
    df.loc[:, "GarageQual"] = df.loc[:, "GarageQual"].fillna("No")
    df.loc[:, "GarageCond"] = df.loc[:, "GarageCond"].fillna("No")
    df.loc[:, "GarageArea"] = df.loc[:, "GarageArea"].fillna(0)
    df.loc[:, "GarageCars"] = df.loc[:, "GarageCars"].fillna(0)
    # HalfBath : NA most likely means no half baths above grade
    df.loc[:, "HalfBath"] = df.loc[:, "HalfBath"].fillna(0)
    # HeatingQC : NA most likely means typical
    df.loc[:, "HeatingQC"] = df.loc[:, "HeatingQC"].fillna("TA")
    # KitchenAbvGr : NA most likely means 0
    df.loc[:, "KitchenAbvGr"] = df.loc[:, "KitchenAbvGr"].fillna(0)
    # KitchenQual : NA most likely means typical
    df.loc[:, "KitchenQual"] = df.loc[:, "KitchenQual"].fillna("TA")
    # LotFrontage : NA most likely means no lot frontage
    df.loc[:, "LotFrontage"] = df.loc[:, "LotFrontage"].fillna(0)
    # LotShape : NA most likely means regular
    df.loc[:, "LotShape"] = df.loc[:, "LotShape"].fillna("Reg")
    # MasVnrType : NA most likely means no veneer
    df.loc[:, "MasVnrType"] = df.loc[:, "MasVnrType"].fillna("None")
    df.loc[:, "MasVnrArea"] = df.loc[:, "MasVnrArea"].fillna(0)
    # MiscFeature : data description says NA means "no misc feature"
    df.loc[:, "MiscFeature"] = df.loc[:, "MiscFeature"].fillna("No")
    df.loc[:, "MiscVal"] = df.loc[:, "MiscVal"].fillna(0)
    # OpenPorchSF : NA most likely means no open porch
    df.loc[:, "OpenPorchSF"] = df.loc[:, "OpenPorchSF"].fillna(0)
    # PavedDrive : NA most likely means not paved
    df.loc[:, "PavedDrive"] = df.loc[:, "PavedDrive"].fillna("N")
    # PoolQC : data description says NA means "no pool"
    df.loc[:, "PoolQC"] = df.loc[:, "PoolQC"].fillna("No")
    df.loc[:, "PoolArea"] = df.loc[:, "PoolArea"].fillna(0)
    # SaleCondition : NA most likely means normal sale
    df.loc[:, "SaleCondition"] = df.loc[:, "SaleCondition"].fillna("Normal")
    # ScreenPorch : NA most likely means no screen porch
    df.loc[:, "ScreenPorch"] = df.loc[:, "ScreenPorch"].fillna(0)
    # TotRmsAbvGrd : NA most likely means 0
    df.loc[:, "TotRmsAbvGrd"] = df.loc[:, "TotRmsAbvGrd"].fillna(0)
    # Utilities : NA most likely means all public utilities
    df.loc[:, "Utilities"] = df.loc[:, "Utilities"].fillna("AllPub")
    # WoodDeckSF : NA most likely means no wood deck
    df.loc[:, "WoodDeckSF"] = df.loc[:, "WoodDeckSF"].fillna(0)
    
    # Представляем некоторые категориальные значения в виде числовых
    # если есть информация о порядке
    df = df.replace({"Alley" : {"None" : 0, "Grvl" : 1, "Pave" : 2},
                       "BsmtCond" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "BsmtExposure" : {"No" : 0, "Mn" : 1, "Av": 2, "Gd" : 3},
                       "BsmtFinType1" : {"No" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4, 
                                         "ALQ" : 5, "GLQ" : 6},
                       "BsmtFinType2" : {"No" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4, 
                                         "ALQ" : 5, "GLQ" : 6},
                       "BsmtQual" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA": 3, "Gd" : 4, "Ex" : 5},
                       "ExterCond" : {"Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5},
                       "ExterQual" : {"Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5},
                       "FireplaceQu" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "Functional" : {"Sal" : 1, "Sev" : 2, "Maj2" : 3, "Maj1" : 4, "Mod": 5, 
                                       "Min2" : 6, "Min1" : 7, "Typ" : 8},
                       "GarageCond" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "GarageQual" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "HeatingQC" : {"Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "KitchenQual" : {"Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "LandSlope" : {"Sev" : 1, "Mod" : 2, "Gtl" : 3},
                       "LotShape" : {"IR3" : 1, "IR2" : 2, "IR1" : 3, "Reg" : 4},
                       "PavedDrive" : {"N" : 0, "P" : 1, "Y" : 2},
                       "PoolQC" : {"No" : 0, "Fa" : 1, "TA" : 2, "Gd" : 3, "Ex" : 4},
                       "Street" : {"Grvl" : 1, "Pave" : 2},
                       "Utilities" : {"ELO" : 1, "NoSeWa" : 2, "NoSewr" : 3, "AllPub" : 4}}
                     )    
    
    # Некоторые числовые переменные на самом деле категориальные
    df = df.replace({"MSSubClass" : {20 : "SC20", 30 : "SC30", 40 : "SC40", 45 : "SC45", 
                                       50 : "SC50", 60 : "SC60", 70 : "SC70", 75 : "SC75", 
                                       80 : "SC80", 85 : "SC85", 90 : "SC90", 120 : "SC120", 
                                       150 : "SC150", 160 : "SC160", 180 : "SC180", 190 : "SC190"},
                       "MoSold" : {1 : "Jan", 2 : "Feb", 3 : "Mar", 4 : "Apr", 5 : "May", 6 : "Jun",
                                   7 : "Jul", 8 : "Aug", 9 : "Sep", 10 : "Oct", 11 : "Nov", 12 : "Dec"}
                      })
    
    return df

# %%
data_tr_clear = clear_data(df_train_test)

# %%
display(data_tr_clear.head(5))
print('shape:', data_tr_clear.shape)
# Out:
#   MSSubClass MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0       SC60       RL         65.0     8450       2      0         4
# 1       SC20       RL         80.0     9600       2      0         4
# 2       SC60       RL         68.0    11250       2      0         3
# 3       SC70       RL         60.0     9550       2      0         3
# 4       SC60       RL         84.0    14260       2      0         3
#
#   LandContour  Utilities LotConfig  ...  Fence MiscFeature MiscVal MoSold  \
# 0         Lvl          4    Inside  ...     No          No       0    Feb
# 1         Lvl          4       FR2  ...     No          No       0    May
# 2         Lvl          4    Inside  ...     No          No       0    Sep
# 3         Lvl          4    Corner  ...     No          No       0    Feb
# 4         Lvl          4       FR2  ...     No          No       0    Dec
#
#   YrSold SaleType  SaleCondition  TotalSF  DolPerFeetNeigLiv  \
# 0   2008       WD         Normal   2566.0         136.783680
# 1   2007       WD         Normal   2524.0         154.980914
# 2   2008       WD         Normal   2706.0         136.783680
# 3   2006       WD        Abnorml   2473.0         120.254826
# 4   2008       WD         Normal   3343.0         132.271687
#
#    DolPerFeetNeigLot
# 0          21.393421
# 1          18.081011
# 2          21.393421
# 3          21.043650
# 4          25.668164
#
# [5 rows x 82 columns]
# shape: (2917, 82)

# %%
def cat_drop(data_tr_clear):
    data_tr_clear.drop(columns=['Street'], inplace=True)
    data_tr_clear.drop(columns=['Utilities'], inplace=True)
    data_tr_clear.drop(columns=['Condition2'], inplace=True)
    data_tr_clear.drop(columns=['RoofMatl'], inplace=True)
    data_tr_clear.drop(columns=['Heating'], inplace=True)
    
    return data_tr_clear

# %%
y = data_train['SalePrice']
# data_tr_clear.drop(columns=['Id', 'SalePrice'], inplace=True)
data_tr_clear = cat_drop(data_tr_clear)

# %%
num_name = data_tr_clear.select_dtypes(exclude='object').columns
cat_name = data_tr_clear.select_dtypes(include='object').columns

# %%
np.sum(np.sum(data_tr_clear[num_name].isnull()) > 0)
# Out:
# 5

# %%
data_tr_clear[num_name] = data_tr_clear[num_name].fillna(data_tr_clear[num_name].median())

# %%
np.sum(data_tr_clear[cat_name].isnull())
# Out:
# MSSubClass       0
# MSZoning         4
# LandContour      0
# LotConfig        0
# Neighborhood     0
# Condition1       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# Exterior1st      1
# Exterior2nd      1
# MasVnrType       0
# Foundation       0
# BsmtCond         0
# CentralAir       0
# Electrical       1
# GarageType       0
# GarageFinish     0
# Fence            0
# MiscFeature      0
# MoSold           0
# SaleType         1
# SaleCondition    0
# dtype: int64

# %%
data_tr_clear['Exterior1st'].value_counts()
# Out:
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     125
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       42
# BrkComm       6
# CBlock        2
# AsphShn       2
# Stone         2
# ImStucc       1
# Name: Exterior1st, dtype: int64

# %%
data_tr_clear['Electrical'] = data_tr_clear['Electrical'].fillna('SBrkr')
data_tr_clear['MSZoning'] = data_tr_clear['MSZoning'].fillna('RL')
data_tr_clear['Exterior1st'] = data_tr_clear['Exterior1st'].fillna('VinylSd')

# %%
[(i, data_tr_clear[i].value_counts().count()) for i in cat_name]
# Out:
# [('MSSubClass', 16),
#  ('MSZoning', 5),
#  ('LandContour', 4),
#  ('LotConfig', 5),
#  ('Neighborhood', 25),
#  ('Condition1', 9),
#  ('BldgType', 5),
#  ('HouseStyle', 8),
#  ('RoofStyle', 6),
#  ('Exterior1st', 15),
#  ('Exterior2nd', 16),
#  ('MasVnrType', 4),
#  ('Foundation', 6),
#  ('BsmtCond', 5),
#  ('CentralAir', 2),
#  ('Electrical', 5),
#  ('GarageType', 7),
#  ('GarageFinish', 4),
#  ('Fence', 5),
#  ('MiscFeature', 5),
#  ('MoSold', 12),
#  ('SaleType', 9),
#  ('SaleCondition', 6)]

# %%
scaler = preprocessing.StandardScaler()
data_tr_scl = pd.DataFrame(scaler.fit_transform(data_tr_clear[num_name]), columns=num_name)

# %%
data_tr_scl = data_tr_clear[num_name]

# %%
data_tr_cat = pd.get_dummies(data_tr_clear[cat_name])

# %%
data_tr_cat.shape
# Out:
# (2917, 184)

# %%
data_tr_scl.shape
# Out:
# (2917, 54)

# %%
data_tr_cat.reset_index(drop=True, inplace=True)
data_tr_scl.reset_index(drop=True, inplace=True)
data_all = pd.concat([data_tr_cat, data_tr_scl], axis=1)

# %%
data_all.shape
# Out:
# (2917, 238)

# %%
X = data_all[:data_train.shape[0]]
X_test = data_all[data_train.shape[0]:]
y = data_train['SalePrice']

# %%
X.shape
# Out:
# (1458, 238)

# %%
X_test.shape
# Out:
# (1459, 238)

# %%
model_xgb = xgboost.XGBRegressor(n_estimators=360, max_depth=2, learning_rate=0.1)
print (rmse_cv(model_xgb, X, np.log1p(y)).mean())
# Out:
# 0.11746

# %%
model_xgb.fit(X,(y))
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=1, missing=None, n_estimators=360,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
model = Sequential()
model.add(Dense(200, activation='relu', input_shape=(data_all.shape[1],)))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(25, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               47800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 74,251
# Trainable params: 74,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adadelta', loss='mse', metrics=['mae'])

# %%
history = model.fit(X, 
                    y, 
                    epochs=100, 
                    validation_split=0.1, 
                    verbose=2)
# Out:
# Train on 1312 samples, validate on 146 samples
# Epoch 1/100
#  - 1s - loss: 18632782321.9512 - mean_absolute_error: 100032.4247 - val_loss: 910577312.4384 - val_mean_absolute_error: 21649.6400
# Epoch 2/100
#  - 0s - loss: 997516497.5610 - mean_absolute_error: 20763.8136 - val_loss: 618931808.0000 - val_mean_absolute_error: 17273.8052
# Epoch 3/100
#  - 0s - loss: 683736155.7073 - mean_absolute_error: 17225.2832 - val_loss: 791839426.6301 - val_mean_absolute_error: 20218.8138
# Epoch 4/100
#  - 0s - loss: 631985721.3659 - mean_absolute_error: 16476.6654 - val_loss: 495747831.2329 - val_mean_absolute_error: 15514.0490
# Epoch 5/100
#  - 0s - loss: 540514445.2683 - mean_absolute_error: 15330.7012 - val_loss: 455221434.7397 - val_mean_absolute_error: 14444.2460
# Epoch 6/100
#  - 0s - loss: 488742158.6341 - mean_absolute_error: 14863.1583 - val_loss: 455116633.4247 - val_mean_absolute_error: 14112.6013
# Epoch 7/100
#  - 0s - loss: 467746951.4146 - mean_absolute_error: 14429.3304 - val_loss: 486015518.2466 - val_mean_absolute_error: 14931.9184
# Epoch 8/100
#  - 0s - loss: 456858081.5610 - mean_absolute_error: 14197.0650 - val_loss: 489728861.8082 - val_mean_absolute_error: 14338.8761
# Epoch 9/100
#  - 0s - loss: 433708319.6098 - mean_absolute_error: 13930.0369 - val_loss: 469659580.4932 - val_mean_absolute_error: 14009.8745
# Epoch 10/100
#  - 0s - loss: 417573308.4878 - mean_absolute_error: 13672.4873 - val_loss: 487579923.7260 - val_mean_absolute_error: 14215.4767
# Epoch 11/100
#  - 0s - loss: 394969009.9512 - mean_absolute_error: 13266.3810 - val_loss: 411934848.0000 - val_mean_absolute_error: 13142.3113
# Epoch 12/100
#  - 0s - loss: 391903007.2195 - mean_absolute_error: 13023.1848 - val_loss: 420218749.8082 - val_mean_absolute_error: 13203.0627
# Epoch 13/100
#  - 0s - loss: 385012558.2439 - mean_absolute_error: 12842.6356 - val_loss: 451089094.5753 - val_mean_absolute_error: 13345.9508
# Epoch 14/100
#  - 0s - loss: 375637142.2439 - mean_absolute_error: 12786.7908 - val_loss: 441624099.9452 - val_mean_absolute_error: 13570.1632
# Epoch 15/100
#  - 0s - loss: 364545027.7073 - mean_absolute_error: 12873.2114 - val_loss: 408539039.5616 - val_mean_absolute_error: 13503.0257
# Epoch 16/100
#  - 0s - loss: 357027393.1707 - mean_absolute_error: 12566.5702 - val_loss: 410749769.6438 - val_mean_absolute_error: 13171.7674
# Epoch 17/100
#  - 0s - loss: 349190507.9024 - mean_absolute_error: 12501.2286 - val_loss: 404214249.2055 - val_mean_absolute_error: 13121.8331
# Epoch 18/100
#  - 0s - loss: 354295237.8537 - mean_absolute_error: 12296.1992 - val_loss: 470427348.1644 - val_mean_absolute_error: 13540.1343
# Epoch 19/100
#  - 0s - loss: 345823876.8780 - mean_absolute_error: 12461.3032 - val_loss: 426196925.8082 - val_mean_absolute_error: 12929.8461
# Epoch 20/100
#  - 0s - loss: 343277011.3171 - mean_absolute_error: 12218.3166 - val_loss: 448480846.9041 - val_mean_absolute_error: 13173.4168
# Epoch 21/100
#  - 0s - loss: 333468648.0000 - mean_absolute_error: 12061.1247 - val_loss: 415964091.1781 - val_mean_absolute_error: 12913.2048
# Epoch 22/100
#  - 0s - loss: 325685018.5366 - mean_absolute_error: 11966.3472 - val_loss: 478524655.3425 - val_mean_absolute_error: 13799.9295
# Epoch 23/100
#  - 0s - loss: 321867706.5366 - mean_absolute_error: 11772.3549 - val_loss: 487137688.5479 - val_mean_absolute_error: 13667.9821
# Epoch 24/100
#  - 0s - loss: 318389198.6341 - mean_absolute_error: 11799.9730 - val_loss: 418603854.9041 - val_mean_absolute_error: 12760.9039
# Epoch 25/100
#  - 0s - loss: 313838432.1951 - mean_absolute_error: 11708.4630 - val_loss: 409857914.7397 - val_mean_absolute_error: 12963.9278
# Epoch 26/100
#  - 0s - loss: 321613373.8537 - mean_absolute_error: 11690.7295 - val_loss: 444371452.4932 - val_mean_absolute_error: 13012.5636
# Epoch 27/100
#  - 0s - loss: 302603462.2439 - mean_absolute_error: 11524.8468 - val_loss: 413628731.6164 - val_mean_absolute_error: 12794.6284
# Epoch 28/100
#  - 0s - loss: 309984419.1220 - mean_absolute_error: 11730.0819 - val_loss: 402277801.6438 - val_mean_absolute_error: 13043.4204
# Epoch 29/100
#  - 0s - loss: 302445956.6829 - mean_absolute_error: 11528.9251 - val_loss: 428475029.9178 - val_mean_absolute_error: 12867.9165
# Epoch 30/100
#  - 0s - loss: 295756605.8537 - mean_absolute_error: 11335.5593 - val_loss: 437594781.8082 - val_mean_absolute_error: 13089.5489
# Epoch 31/100
#  - 0s - loss: 297358745.1707 - mean_absolute_error: 11329.4936 - val_loss: 420757074.4110 - val_mean_absolute_error: 12898.4256
# Epoch 32/100
#  - 0s - loss: 283771032.7805 - mean_absolute_error: 11099.0287 - val_loss: 402042762.9589 - val_mean_absolute_error: 12818.7561
# Epoch 33/100
#  - 0s - loss: 291592299.5122 - mean_absolute_error: 11180.4449 - val_loss: 441769102.9041 - val_mean_absolute_error: 12997.0739
# Epoch 34/100
#  - 0s - loss: 287958005.0732 - mean_absolute_error: 11182.1125 - val_loss: 416052471.6712 - val_mean_absolute_error: 12732.0551
# Epoch 35/100
#  - 0s - loss: 281983115.5122 - mean_absolute_error: 11032.5235 - val_loss: 441346166.7945 - val_mean_absolute_error: 13052.6241
# Epoch 36/100
#  - 0s - loss: 278332172.6829 - mean_absolute_error: 10994.7116 - val_loss: 465428669.8082 - val_mean_absolute_error: 13309.9404
# Epoch 37/100
#  - 0s - loss: 275370572.6829 - mean_absolute_error: 10951.3047 - val_loss: 464362410.0822 - val_mean_absolute_error: 13231.4126
# Epoch 38/100
#  - 0s - loss: 276978725.3659 - mean_absolute_error: 10950.0998 - val_loss: 422796413.8082 - val_mean_absolute_error: 12904.4038
# Epoch 39/100
#  - 0s - loss: 273474172.8780 - mean_absolute_error: 10936.5431 - val_loss: 436368690.8493 - val_mean_absolute_error: 12986.4539
# Epoch 40/100
#  - 0s - loss: 271998062.6341 - mean_absolute_error: 10760.5170 - val_loss: 460164322.6301 - val_mean_absolute_error: 13249.9071
# Epoch 41/100
#  - 0s - loss: 268756479.1220 - mean_absolute_error: 10800.5723 - val_loss: 401090559.5616 - val_mean_absolute_error: 12593.8609
# Epoch 42/100
#  - 0s - loss: 263209414.2439 - mean_absolute_error: 10688.7303 - val_loss: 423186526.2466 - val_mean_absolute_error: 12742.5176
# Epoch 43/100
#  - 0s - loss: 258302200.1951 - mean_absolute_error: 10580.4298 - val_loss: 535105695.5616 - val_mean_absolute_error: 14253.4405
# Epoch 44/100
#  - 0s - loss: 262973126.2439 - mean_absolute_error: 10677.4814 - val_loss: 402226954.9589 - val_mean_absolute_error: 12724.7070
# Epoch 45/100
#  - 0s - loss: 260623312.1951 - mean_absolute_error: 10654.8151 - val_loss: 430660334.0274 - val_mean_absolute_error: 12786.1192
# Epoch 46/100
#  - 0s - loss: 253719942.3415 - mean_absolute_error: 10508.8530 - val_loss: 424640627.7260 - val_mean_absolute_error: 12747.1866
# Epoch 47/100
#  - 0s - loss: 254312671.0244 - mean_absolute_error: 10372.2043 - val_loss: 454400813.1507 - val_mean_absolute_error: 13068.4877
# Epoch 48/100
#  - 0s - loss: 247282535.0244 - mean_absolute_error: 10295.0418 - val_loss: 413146904.5479 - val_mean_absolute_error: 12754.5787
# Epoch 49/100
#  - 0s - loss: 246393171.5122 - mean_absolute_error: 10296.2130 - val_loss: 536524988.4932 - val_mean_absolute_error: 14175.5208
# Epoch 50/100
#  - 0s - loss: 251066478.0488 - mean_absolute_error: 10332.0260 - val_loss: 410260515.9452 - val_mean_absolute_error: 12825.8477
# Epoch 51/100
#  - 0s - loss: 245515617.9512 - mean_absolute_error: 10276.8964 - val_loss: 437977660.0548 - val_mean_absolute_error: 12930.2347
# Epoch 52/100
#  - 0s - loss: 244777679.2195 - mean_absolute_error: 10223.1654 - val_loss: 420826344.3288 - val_mean_absolute_error: 12711.6632
# Epoch 53/100
#  - 0s - loss: 247024432.3902 - mean_absolute_error: 10264.7988 - val_loss: 490974277.2603 - val_mean_absolute_error: 13595.4025
# Epoch 54/100
#  - 0s - loss: 238958613.6585 - mean_absolute_error: 10082.7743 - val_loss: 404348160.0000 - val_mean_absolute_error: 13120.9645
# Epoch 55/100
#  - 0s - loss: 243513164.6829 - mean_absolute_error: 10057.3388 - val_loss: 415542577.0959 - val_mean_absolute_error: 13018.3562
# Epoch 56/100
#  - 0s - loss: 237161795.6098 - mean_absolute_error: 10005.4190 - val_loss: 413274146.6301 - val_mean_absolute_error: 12823.9013
# Epoch 57/100
#  - 0s - loss: 231321940.6829 - mean_absolute_error: 9922.7193 - val_loss: 410711116.2740 - val_mean_absolute_error: 13015.4433
# Epoch 58/100
#  - 0s - loss: 234695740.0976 - mean_absolute_error: 10029.4395 - val_loss: 415282451.2877 - val_mean_absolute_error: 12874.9742
# Epoch 59/100
#  - 0s - loss: 230108445.4634 - mean_absolute_error: 9830.3847 - val_loss: 410455022.0274 - val_mean_absolute_error: 12843.1740
# Epoch 60/100
#  - 0s - loss: 227456617.5610 - mean_absolute_error: 9845.0853 - val_loss: 427134670.0274 - val_mean_absolute_error: 12906.5830
# Epoch 61/100
#  - 0s - loss: 231240399.2195 - mean_absolute_error: 9902.6418 - val_loss: 442041932.7123 - val_mean_absolute_error: 13095.5284
# Epoch 62/100
#  - 0s - loss: 221649841.5610 - mean_absolute_error: 9704.5614 - val_loss: 461091128.9863 - val_mean_absolute_error: 13289.4317
# Epoch 63/100
#  - 0s - loss: 215820144.4878 - mean_absolute_error: 9574.2107 - val_loss: 417324611.0685 - val_mean_absolute_error: 12885.8674
# Epoch 64/100
#  - 0s - loss: 217672459.1220 - mean_absolute_error: 9722.9770 - val_loss: 406421866.9589 - val_mean_absolute_error: 12746.2242
# Epoch 65/100
#  - 0s - loss: 215797919.6098 - mean_absolute_error: 9576.3593 - val_loss: 439603470.9041 - val_mean_absolute_error: 13052.0212
# Epoch 66/100
#  - 0s - loss: 218272082.7317 - mean_absolute_error: 9560.4302 - val_loss: 403109956.3836 - val_mean_absolute_error: 12942.0908
# Epoch 67/100
#  - 0s - loss: 211918215.4146 - mean_absolute_error: 9327.6153 - val_loss: 471430714.3014 - val_mean_absolute_error: 13423.0150
# Epoch 68/100
#  - 0s - loss: 214034305.9512 - mean_absolute_error: 9637.9117 - val_loss: 457336518.5753 - val_mean_absolute_error: 13233.9106
# Epoch 69/100
#  - 0s - loss: 214430411.9024 - mean_absolute_error: 9497.1781 - val_loss: 419655108.3836 - val_mean_absolute_error: 12907.3405
# Epoch 70/100
#  - 0s - loss: 206098955.9024 - mean_absolute_error: 9325.4147 - val_loss: 423984144.2192 - val_mean_absolute_error: 13048.7091
# Epoch 71/100
#  - 0s - loss: 203609861.1707 - mean_absolute_error: 9242.5060 - val_loss: 512242079.1233 - val_mean_absolute_error: 13923.9638
# Epoch 72/100
#  - 0s - loss: 208614156.2927 - mean_absolute_error: 9452.6305 - val_loss: 540682661.2603 - val_mean_absolute_error: 14329.3830
# Epoch 73/100
#  - 0s - loss: 203271518.8293 - mean_absolute_error: 9267.9878 - val_loss: 450276407.6712 - val_mean_absolute_error: 13222.3381
# Epoch 74/100
#  - 0s - loss: 202362981.4634 - mean_absolute_error: 9228.8230 - val_loss: 432406140.4932 - val_mean_absolute_error: 13057.2121
# Epoch 75/100
#  - 0s - loss: 201194611.6098 - mean_absolute_error: 9146.6711 - val_loss: 430658555.6164 - val_mean_absolute_error: 13060.6426
# Epoch 76/100
#  - 0s - loss: 195341821.9512 - mean_absolute_error: 8982.6025 - val_loss: 456918271.1233 - val_mean_absolute_error: 13312.6050
# Epoch 77/100
#  - 0s - loss: 191056857.7561 - mean_absolute_error: 8923.2334 - val_loss: 418495240.7671 - val_mean_absolute_error: 13068.1385
# Epoch 78/100
#  - 0s - loss: 195985138.0488 - mean_absolute_error: 9078.3442 - val_loss: 441664869.2603 - val_mean_absolute_error: 13262.9798
# Epoch 79/100
#  - 0s - loss: 187320584.2927 - mean_absolute_error: 8823.5035 - val_loss: 414853338.3014 - val_mean_absolute_error: 13074.3056
# Epoch 80/100
#  - 0s - loss: 188247481.0732 - mean_absolute_error: 8796.0260 - val_loss: 444334278.1370 - val_mean_absolute_error: 13238.6326
# Epoch 81/100
#  - 0s - loss: 187804485.7561 - mean_absolute_error: 8791.4015 - val_loss: 481760291.9452 - val_mean_absolute_error: 13670.8672
# Epoch 82/100
#  - 0s - loss: 188967829.5610 - mean_absolute_error: 8843.5349 - val_loss: 414790677.4795 - val_mean_absolute_error: 13266.6730
# Epoch 83/100
#  - 0s - loss: 178182734.4390 - mean_absolute_error: 8658.9041 - val_loss: 469665765.6986 - val_mean_absolute_error: 13530.9198
# Epoch 84/100
#  - 0s - loss: 181065415.4146 - mean_absolute_error: 8636.8851 - val_loss: 512358063.3425 - val_mean_absolute_error: 13944.5311
# Epoch 85/100
#  - 0s - loss: 180464685.6585 - mean_absolute_error: 8495.9701 - val_loss: 464860666.7397 - val_mean_absolute_error: 13324.1833
# Epoch 86/100
#  - 0s - loss: 185404499.6098 - mean_absolute_error: 8697.5503 - val_loss: 468293735.0137 - val_mean_absolute_error: 13422.4732
# Epoch 87/100
#  - 0s - loss: 175290483.9024 - mean_absolute_error: 8534.4395 - val_loss: 430594400.4384 - val_mean_absolute_error: 13270.0397
# Epoch 88/100
#  - 0s - loss: 176458069.7561 - mean_absolute_error: 8488.3657 - val_loss: 443562336.8767 - val_mean_absolute_error: 13262.0976
# Epoch 89/100
#  - 0s - loss: 166026140.5854 - mean_absolute_error: 8216.6198 - val_loss: 452793978.7397 - val_mean_absolute_error: 13376.3197
# Epoch 90/100
#  - 0s - loss: 165754207.8049 - mean_absolute_error: 8216.0676 - val_loss: 506847407.7808 - val_mean_absolute_error: 13833.0876
# Epoch 91/100
#  - 0s - loss: 167907912.5854 - mean_absolute_error: 8258.1016 - val_loss: 481587808.8767 - val_mean_absolute_error: 13577.2223
# Epoch 92/100
#  - 0s - loss: 168863581.3659 - mean_absolute_error: 8273.2419 - val_loss: 490289046.3562 - val_mean_absolute_error: 13609.9604
# Epoch 93/100
#  - 0s - loss: 169048512.4878 - mean_absolute_error: 8272.8277 - val_loss: 451720676.3836 - val_mean_absolute_error: 13426.1200
# Epoch 94/100
#  - 0s - loss: 162514130.2439 - mean_absolute_error: 8165.2942 - val_loss: 503517980.4932 - val_mean_absolute_error: 13825.9904
# Epoch 95/100
#  - 0s - loss: 162525409.4634 - mean_absolute_error: 8046.4733 - val_loss: 455114418.4110 - val_mean_absolute_error: 13346.9203
# Epoch 96/100
#  - 0s - loss: 162091981.0732 - mean_absolute_error: 7987.2568 - val_loss: 463283265.7534 - val_mean_absolute_error: 13495.7303
# Epoch 97/100
#  - 0s - loss: 157037937.6585 - mean_absolute_error: 7907.2604 - val_loss: 477241333.0411 - val_mean_absolute_error: 13633.0444
# Epoch 98/100
#  - 0s - loss: 155682288.3902 - mean_absolute_error: 7844.0051 - val_loss: 463079374.0274 - val_mean_absolute_error: 13452.5467
# Epoch 99/100
#  - 0s - loss: 153226165.6585 - mean_absolute_error: 7936.7613 - val_loss: 465514918.5753 - val_mean_absolute_error: 13513.7575
# Epoch 100/100
#  - 0s - loss: 155771309.8537 - mean_absolute_error: 7850.2407 - val_loss: 525319931.1781 - val_mean_absolute_error: 14163.5099

# %%
pred_NN = model.predict(X_test)
out_NN = np.column_stack((data_test['Id'], pred_NN))
np.savetxt('submission_NN.csv', out_NN, header="Id,SalePrice", 
            comments="", fmt="%d,%f")

# %%
pred = model_xgb.predict(X_test)

# %%
pred
# Out:
# array([123986.85, 164452.44, 189940.56, ..., 163842.95, 120324.43,
#        216664.67], dtype=float32)

# %%
out = np.column_stack((data_test['Id'], pred))

# %%
np.savetxt('submission1.csv', out, header="Id,SalePrice", 
            comments="", fmt="%d,%f")
